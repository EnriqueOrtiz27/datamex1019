# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
#I chose Promos homme (Men's Promotions)
#https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=84&sort=sale

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here

import pandas as pd
import json
import requests 
from pandas.io.json import json_normalize

# %%
url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=84&sort=sale'

# %%
header = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36'}

response = requests.get(url, headers=header)
results = response.json()


flattened_data = json_normalize(results)

flattened_data1 = json_normalize(flattened_data.articles[0])

# %%
flattened_data1
# Out:
#               sku                                               name  \
# 0   YO122SA4V-H11                           Sweat à capuche - orange
# 1   JAM22E00U-C11        JJIMARCO JJCONNOR CHECK - Chino - dark grey
# 2   TOB22O04Y-K11     COLORBLOCKED TAPE TEE - T-shirt imprimé - blue
# 3   SIF22E01L-K11          PANTS - Pantalon cargo - light blue denim
# 4   AD115O0G9-A11  AMERICANA - Baskets basses - footwear white/co...
# ..            ...                                                ...
# 79  JA222G0VG-Q11      JJIGLENN JJORIGINAL - Jean slim - black denim
# 80  AD122O0GM-Q11                 TECH TEE - T-shirt imprimé - black
# 81  BB112B00J-Q11                    RACING - Baskets basses - black
# 82  PU112O03I-A11  RS-X HARD DRIVE - Baskets basses - white/galax...
# 83  OS322G0BY-K11            ONSLOOM WASHED - Jean slim - blue denim
#
#                                                 sizes  \
# 0                                 [XXS, S, M, L, XXL]
# 1   [27x30, 27x32, 28x32, 29x32, 29x34, 30x32, 30x...
# 2                              [XS, S, M, L, XL, XXL]
# 3                                  [S, M, L, XL, XXL]
# 4   [36, 38, 40, 42, 44, 46, 48, 36 2/3, 37 1/3, 3...
# ..                                                ...
# 79  [27x30, 27x32, 28x30, 28x32, 29x30, 29x32, 29x...
# 80                             [XS, S, M, L, XL, XXL]
# 81                           [39, 40, 42, 43, 44, 45]
# 82  [36, 37, 37.5, 38, 38.5, 39, 40, 40.5, 41, 42,...
# 83  [29x32, 29x34, 30x32, 30x34, 31x30, 31x32, 31x...
#
#                                               url_key  \
# 0            yourturn-sweatshirt-orange-yo122sa4v-h11
# 1   jack-and-jones-premium-jjimarco-jjconnor-check...
# 2   tommy-jeans-colorblocked-tape-tee-t-shirt-impr...
# 3   siksilk-pantalon-cargo-light-blue-denim-sif22e...
# 4   adidas-originals-americana-baskets-basses-foot...
# ..                                                ...
# 79  jack-and-jones-jjiglenn-jjoriginal-jean-slim-b...
# 80  adidas-originals-tech-tee-t-shirt-imprime-ad12...
# 81     boss-racing-baskets-basses-black-bb112b00j-q11
# 82  puma-rs-x-hard-drive-baskets-basses-whitegalax...
# 83  only-and-sons-onsloom-washed-jean-slim-blue-de...
#
#                                                 media            brand_name  \
# 0   [{'path': 'YO/12/2S/A4/VH/11/YO122SA4V-H11@9.j...              YOURTURN
# 1   [{'path': 'JA/M2/2E/00/UC/11/JAM22E00U-C11@6.j...  Jack & Jones PREMIUM
# 2   [{'path': 'TO/B2/2O/04/YK/11/TOB22O04Y-K11@10....           Tommy Jeans
# 3   [{'path': 'SI/F2/2E/01/LK/11/SIF22E01L-K11@7.j...               SIKSILK
# 4   [{'path': 'AD/11/5O/0G/9A/11/AD115O0G9-A11@11....      adidas Originals
# ..                                                ...                   ...
# 79  [{'path': 'JA/22/2G/0V/GQ/11/JA222G0VG-Q11@20....          Jack & Jones
# 80  [{'path': 'AD/12/2O/0G/MQ/11/AD122O0GM-Q11@9.j...      adidas Originals
# 81  [{'path': 'BB/11/2B/00/JQ/11/BB112B00J-Q11@12....                  BOSS
# 82  [{'path': 'PU/11/2O/03/IA/11/PU112O03I-A11@8.j...                  Puma
# 83  [{'path': 'OS/32/2G/0B/YK/11/OS322G0BY-K11@17....           Only & Sons
#
#     is_premium                                    family_articles  \
# 0        False  [{'sku': 'YO122SA4V-H11', 'url_key': 'yourturn...
# 1        False  [{'sku': 'JAM22E00U-C11', 'url_key': 'jack-and...
# 2        False  [{'sku': 'TOB22O04Y-K11', 'url_key': 'tommy-je...
# 3        False  [{'sku': 'SIF22E01L-K11', 'url_key': 'siksilk-...
# 4        False  [{'sku': 'AD115O0G9-A11', 'url_key': 'adidas-o...
# ..         ...                                                ...
# 79       False  [{'sku': 'JA222G0VG-Q11', 'url_key': 'jack-and...
# 80       False  [{'sku': 'AD122O0GM-Q11', 'url_key': 'adidas-o...
# 81        True  [{'sku': 'BB112B00J-Q11', 'url_key': 'boss-rac...
# 82       False  [{'sku': 'PU112O03I-A11', 'url_key': 'puma-rs-...
# 83       False  [{'sku': 'OS322G0BY-K11', 'url_key': 'only-and...
#
#                                                 flags product_group  \
# 0   [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 1   [{'key': 'discountRate', 'value': 'Jusqu’à -20...      clothing
# 2   [{'key': 'discountRate', 'value': '-30%', 'tra...      clothing
# 3   [{'key': 'discountRate', 'value': '-15%', 'tra...      clothing
# 4   [{'key': 'discountRate', 'value': 'Jusqu’à -30...          shoe
# ..                                                ...           ...
# 79  [{'key': 'discountRate', 'value': 'Jusqu’à -20...      clothing
# 80  [{'key': 'discountRate', 'value': '-15%', 'tra...      clothing
# 81  [{'key': 'discountRate', 'value': '-15%', 'tra...          shoe
# 82  [{'key': 'discountRate', 'value': 'Jusqu’à -20...          shoe
# 83  [{'key': 'discountRate', 'value': '-35%', 'tra...      clothing
#
#    delivery_promises price.original price.promotional  \
# 0                 []        29,99 €           23,99 €
# 1                 []        59,99 €           47,99 €
# 2                 []        39,95 €           27,95 €
# 3                 []        59,95 €           50,95 €
# 4                 []        79,95 €           55,95 €
# ..               ...            ...               ...
# 79                []        39,99 €           31,99 €
# 80                []        29,95 €           25,45 €
# 81                []       249,95 €          211,95 €
# 82                []       109,95 €           87,95 €
# 83                []        43,99 €           28,59 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                        False                                False
# 1                         True                                False
# 2                        False                                False
# 3                        False                                False
# 4                         True                                False
# ..                         ...                                  ...
# 79                        True                                False
# 80                       False                                False
# 81                       False                                False
# 82                        True                                False
# 83                       False                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                     True
# 2                                    False
# 3                                    False
# 4                                     True
# ..                                     ...
# 79                                    True
# 80                                   False
# 81                                   False
# 82                                    True
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 79                                      False
# 80                                      False
# 81                                      False
# 82                                      False
# 83                                      False
#
#                                               outfits
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                                NaN
# 80  [{'id': 'fVdjFG9hTsW', 'url_key': '/outfits/fV...
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
#
# [84 rows x 18 columns]

# %%
# Get the total number of pages
total_pages= results['pagination']['page_count']

# Your code

df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset={k}&sort=sale'
    response = requests.get(url, headers=header)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
df.head()

# %%
df.dtypes

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
#Trending brand: 
df.brand_name.value_counts().index[0]

# %%
#Products with the highest discount
#Similar to the guided lesson but we group by product and not by brand:
df['price.original']=df['price.original'].astype(str)
df['price.promotional']=df['price.promotional'].astype(str)


df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')


df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['name']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]

# %%
#sum of all discounts

df['discount_amount'].sum()
