# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)
fig, ax1 = plt.subplots(1,1)
ax1 = plt.plot(x,y)

# %%
fig, ax2 = plt.subplots(1,1)
ax2 = plt.plot(x,z)

# %%
#Second version. I didn't get how to use the index argument. 
sns.set_style('darkgrid')
fig, [f1,f2] = plt.subplots(nrows=1, ncols=2)
f1.plot(x,y, linewidth=2)
f2.plot(x,z)
plt.show();

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
# your code here-2st way (call `subplots` only once not using the `index` parameter)
fig, [f1,f2] = plt.subplots(nrows=1, ncols=2, figsize=(15,6))
f1.plot(x,y, linewidth=2)
f2.plot(x,z)
plt.show();

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
fig, [f1,f2] = plt.subplots(nrows=1, ncols=2, figsize=(15,6))
f1.plot(x,y, linewidth=2)
f1.set_xlabel("x_values")
f1.set_ylabel("y_values")
f2.plot(x,z)
f2.set_xlabel("x_values")
f2.set_ylabel("z_values")
plt.show();

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here
#escala normal
fig, ax1 = plt.subplots()
ax1.set_yscale('linear')
ax1.set_xscale('linear')
y2 = np.exp(x)
ax1.plot(x,y2)

ax1.plot(x,y)
plt.show();

# %%
#escala logarítmica
fig, ax1 = plt.subplots(figsize=(5,5))
ax1.set_yscale('log')
ax1.set_xscale('log')
y2 = np.exp(x)
ax1.plot(x,y2)

ax1.plot(x,y)
plt.show();

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
data = pd.read_csv('vehicles.csv')

# %%
x = data['Combined MPG']
y = data['Highway MPG']

# %%
plt.scatter(x,y,s=5)
plt.xlabel("Combined MPG")
plt.ylabel("Highway MPG")
plt.show();

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here
z = data['CO2 Emission Grams/Mile']

# %%
data.boxplot(column='CO2 Emission Grams/Mile'); #pandas

# %%
sns.boxplot(x= 'CO2 Emission Grams/Mile', data=data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
x = data['Fuel Barrels/Year']
y = range(int(data['Fuel Barrels/Year'].min()),  int(data['Fuel Barrels/Year'].max()))

# %%
sns.distplot(x, bins=15);

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
ax = sns.barplot(x="Fuel Type", y="City MPG", data=data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Regular'),
#  Text(0, 0, 'Premium'),
#  Text(0, 0, 'Diesel'),
#  Text(0, 0, 'Premium and Electricity'),
#  Text(0, 0, 'Premium or E85'),
#  Text(0, 0, 'Premium Gas or Electricity'),
#  Text(0, 0, 'Gasoline or E85'),
#  Text(0, 0, 'Gasoline or natural gas'),
#  Text(0, 0, 'CNG'),
#  Text(0, 0, 'Regular Gas or Electricity'),
#  Text(0, 0, 'Midgrade'),
#  Text(0, 0, 'Regular Gas and Electricity'),
#  Text(0, 0, 'Gasoline or propane')]
