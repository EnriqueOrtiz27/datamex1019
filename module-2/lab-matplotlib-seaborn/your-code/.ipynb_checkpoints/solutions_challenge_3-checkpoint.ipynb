# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes('number').columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
#your code here- categorical variable
titanic.select_dtypes(exclude=['number']).columns
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
sns.set_style('white')

# %%
sns.set(rc={'figure.figsize':(12,6)})

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
x = titanic.Age
sns.distplot(x,bins=10);

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
fig,[ax1,ax2,ax3]  = plt.subplots(1,3)
ax1.hist(x, bins=10)
ax2.hist(x, bins=20)
ax3.hist(x, bins=50)
plt.show();

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here
#Well, the more bins you have, the fewer observation each bin contains.

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
#puse esa gráfica arriba :)

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
y = titanic.groupby('Gender',as_index=False).agg('count')
plt.bar(y.Gender, y.PassengerId)
y
# Out:
#    Gender  PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  \
# 0  female          466       314     466   466  466    466    466     466
# 1    male          843       577     843   843  843    843    843     843
#
#    Fare  Cabin  Embarked
# 0   466    466       466
# 1   843    843       843

# %%
x = ['Male', 'Female']
yy = [466,843]
sns.barplot(x=x, y=yy)
#más bonito con seaborn.

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
z = titanic.Pclass

plt.hist(z,bins=3)
plt.xticks([1,2,3])
plt.xlabel("Class Type")
plt.ylabel("Frequency")
plt.show();

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.
# z

# %%
# your code here
#aquí puse lo que era sobre Class, abajo pongo lo de las stats de Age. Borré sin querer el MarkDown. 
x = ['Class 1', 'Class 2', 'Class 3']
z = [323, 277, 709]
sns.barplot(x=x, y=z)

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
#aquí apenas pongo las stats sobre Age

stats = titanic.Age
sns.boxplot(stats);

"""   
Lo que me dice es que hay bastantes outliers hacia el extremo derecho;
a saber: muchos viejitos en el Titanic. Si ignoramos esos datos, la distribución se ve
aproximadamente simétrica, aunque hay más datos en general del lado derecho.
La mediana es un poco inferior a los 30 años. La varianza es grande también: véase el tamaño de la caja versus
los brazos. 
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
#está arriba, pero la incluyo de nuevo. 
x = titanic.Age
sns.distplot(x,bins=10);

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here
"""
Esto nos deja comprobar lo escrito anteriormente: a saber, que la distribución está
sesgada a la derecha. Algo nuevo que podemos ver es que el grueso de los tripulantes 
está entre los 20 y los 40 años. Supongo que eso se podría colegir del gráfico pasado,
pero aquí es más claro. 

"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
sns.lmplot(x='Age', y='Fare', data=titanic)

# %%
# your code-2nd way
x=titanic.Age
y=titanic.Fare
coef = np.polyfit(x,y,1)
poly1d_fn = np.poly1d(coef) 
# poly1d_fn is now a function which takes in x and returns an estimate for y

plt.plot(x,y, 'yo', x, poly1d_fn(x), '--k')
plt.xlim(0, 100)
plt.ylim(0, 200)
plt.show();

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
#sns.heatmap(titanic.Fare,titanic.Survived)

df = titanic[['Age', 'Survived', 'Fare', 'Pclass']]

sns.heatmap(df)

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
"""
Como podemos ver en este gráfico, es difícil notar alguna correlación de interés.
Obviamente, mientras la clase sube, el "fare" también (notar que clase 1 es la
más alta). Pero no parece que la gente
más joven haya sobrevivido más que los viejos. 
"""
pd.plotting.scatter_matrix(df)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1278a9ad0>,
# ...
#       dtype=object)

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here

df2 = titanic[titanic.Pclass==1]

# %%
stats = df2.Age
sns.boxplot(stats);
#Clase 1

# %%
df2 = titanic[titanic.Pclass==2]
stats = df2.Age
sns.boxplot(stats);
#Clase 2

# %%
df2 = titanic[titanic.Pclass==3]
stats = df2.Age
sns.boxplot(stats);
#Clase 3

# %%
"""
Podemos ver que en la clase más económica, la número 3, hay más jóvenes, porque #estudiambre. 
En la clase 1, la más cara, hay más viejitos, porque #mepensiono #prevenIMSS
"""

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
#no me salió con Facetgrid entonces lo hice así:
v = titanic[['Gender', 'Age']]
m = v[v.Gender=='male']
x = m.Age
sns.distplot(x,bins=10);
#esta es la distribución de los hombres

# %%
#g = sns.FacetGrid(m)
#g.map(plt.hist, "Age by Gender");
m = v[v.Gender=='female']
x = m.Age
sns.distplot(x,bins=10);
#esta es la distribución de las mujeres
